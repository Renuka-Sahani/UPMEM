# %%
import numpy as np

# Constants
N_POINTS = 10000
DIMENSIONS = 2
K = 6
MAX_ITERATIONS = 15

# Predefined centroids to be consistent with the C implementation
predefined_centroids = np.array([
    [1.0, 1.0],   # Centroid for cluster 1
    [5.0, 5.0],   # Centroid for cluster 2
    [9.0, 9.0],   # Centroid for cluster 3
    [13.0, 13.0], # Centroid for cluster 4
    [17.0, 17.0], # Centroid for cluster 5
    [21.0, 21.0]  # Centroid for cluster 6
])

# Function to generate points around predefined centroids without randomness
def generate_simple_clusters():
    points = np.zeros((N_POINTS, DIMENSIONS))
    points_per_cluster = N_POINTS // K

    for i in range(K):
        for j in range(points_per_cluster):
            index = i * points_per_cluster + j
            points[index] = predefined_centroids[i]  # No random variation

    return points

# Function to calculate the Euclidean distance between two points
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# K-means clustering functions (assign clusters and update centroids)
def assign_clusters(points, centroids):
    clusters = np.zeros(N_POINTS, dtype=int)
    for i in range(N_POINTS):
        distances = np.array([euclidean_distance(points[i], centroid) for centroid in centroids])
        clusters[i] = np.argmin(distances)
    return clusters

def update_centroids(points, clusters):
    new_centroids = np.zeros((K, DIMENSIONS))
    count = np.zeros(K)

    for i in range(N_POINTS):
        cluster_id = clusters[i]
        new_centroids[cluster_id] += points[i]
        count[cluster_id] += 1

    for j in range(K):
        if count[j] != 0:
            new_centroids[j] /= count[j]

    return new_centroids

# Function to print centroids
def print_centroids(title, centroids):
    print(f"{title}:")
    for i in range(K):
        print(f"Centroid {i}: {centroids[i]}")

# Main function
def kmeans_clustering():
    points = generate_simple_clusters()

    # Initialize centroids with fixed predefined points
    centroids = predefined_centroids.copy()

    print_centroids("Initial Centroids", centroids)

    for iteration in range(MAX_ITERATIONS):
        print(f"\nIteration {iteration + 1}:")
        clusters = assign_clusters(points, centroids)
        centroids = update_centroids(points, clusters)
        print_centroids("Updated Centroids", centroids)

    print_centroids("Final Centroids", centroids)

# Run the main function
kmeans_clustering()
# Out:
# Initial Centroids:
# Centroid 0: [1. 1.]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 1:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 2:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 3:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 4:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 5:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 6:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 7:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 8:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 9:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 10:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 11:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 12:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 13:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 14:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 15:
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Final Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]

# %%
import numpy as np
import time

# Constants
N_POINTS = 10000
DIMENSIONS = 2
K = 6
MAX_ITERATIONS = 15

# Generate predefined clusters around fixed centroids
def generate_fixed_clusters():
    predefined_centroids = np.array([
        [1.0, 1.0],
        [5.0, 5.0],
        [9.0, 9.0],
        [13.0, 13.0],
        [17.0, 17.0],
        [21.0, 21.0]
    ])
    points = np.zeros((N_POINTS, DIMENSIONS))
    points_per_cluster = N_POINTS // K

    for i in range(K):
        for j in range(points_per_cluster):
            index = i * points_per_cluster + j
            points[index] = predefined_centroids[i]

    return points

# Simple function to calculate Euclidean distance
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# K-means clustering functions (assign clusters and update centroids)
def assign_clusters(points, centroids):
    clusters = np.zeros(N_POINTS, dtype=int)
    for i in range(N_POINTS):
        distances = np.array([euclidean_distance(points[i], centroids[j]) for j in range(K)])
        clusters[i] = np.argmin(distances)
    return clusters

def update_centroids(points, clusters):
    new_centroids = np.zeros((K, DIMENSIONS))
    count = np.zeros(K)

    for i in range(N_POINTS):
        new_centroids[clusters[i]] += points[i]
        count[clusters[i]] += 1

    for j in range(K):
        if count[j] != 0:
            new_centroids[j] /= count[j]

    return new_centroids

# Function to print centroids
def print_centroids(title, centroids):
    print(f"{title}:")
    for i in range(K):
        print(f"Centroid {i}: {centroids[i]}")

# Main function
def kmeans_clustering():
    points = generate_fixed_clusters()

    centroids = np.array([
        [1.1, 1.1],
        [5.1, 5.1],
        [9.1, 9.1],
        [13.1, 13.1],
        [17.1, 17.1],
        [21.1, 21.1]
    ])

    print_centroids("Initial Centroids", centroids)

    total_start_time = time.time()

    for iteration in range(MAX_ITERATIONS):
        print(f"\nIteration {iteration + 1}:")

        start_time = time.time()
        clusters = assign_clusters(points, centroids)
        end_time = time.time()
        print(f"Assign clusters duration: {end_time - start_time} seconds")

        start_time = time.time()
        centroids = update_centroids(points, clusters)
        end_time = time.time()
        print(f"Update centroids duration: {end_time - start_time} seconds")

        print_centroids("Updated Centroids", centroids)

    total_end_time = time.time()
    print(f"Total duration: {total_end_time - total_start_time} seconds")

    print_centroids("Final Centroids", centroids)

# Run the main function
kmeans_clustering()
# Out:
# Initial Centroids:
# Centroid 0: [1.1 1.1]
# Centroid 1: [5.1 5.1]
# Centroid 2: [9.1 9.1]
# Centroid 3: [13.1 13.1]
# Centroid 4: [17.1 17.1]
# Centroid 5: [21.1 21.1]
#
# Iteration 1:
# Assign clusters duration: 0.7463226318359375 seconds
# Update centroids duration: 0.017658233642578125 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 2:
# Assign clusters duration: 0.7595312595367432 seconds
# Update centroids duration: 0.01782059669494629 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 3:
# Assign clusters duration: 0.8407690525054932 seconds
# Update centroids duration: 0.01931285858154297 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 4:
# Assign clusters duration: 0.7560434341430664 seconds
# Update centroids duration: 0.017249584197998047 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 5:
# Assign clusters duration: 0.814030647277832 seconds
# Update centroids duration: 0.01719355583190918 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 6:
# Assign clusters duration: 0.754622220993042 seconds
# Update centroids duration: 0.018901824951171875 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 7:
# Assign clusters duration: 0.7265160083770752 seconds
# Update centroids duration: 0.01792454719543457 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 8:
# Assign clusters duration: 0.6425909996032715 seconds
# Update centroids duration: 0.017752408981323242 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 9:
# Assign clusters duration: 0.7997350692749023 seconds
# Update centroids duration: 0.028730392456054688 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 10:
# Assign clusters duration: 0.7722866535186768 seconds
# Update centroids duration: 0.017118453979492188 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 11:
# Assign clusters duration: 0.7990939617156982 seconds
# Update centroids duration: 0.017775774002075195 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 12:
# Assign clusters duration: 0.7098243236541748 seconds
# Update centroids duration: 0.03287339210510254 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 13:
# Assign clusters duration: 0.814507007598877 seconds
# Update centroids duration: 0.028664112091064453 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 14:
# Assign clusters duration: 0.7770030498504639 seconds
# Update centroids duration: 0.032167673110961914 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 15:
# Assign clusters duration: 0.8117465972900391 seconds
# Update centroids duration: 0.03164315223693848 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Total duration: 11.918341159820557 seconds
# Final Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]

# %%
import numpy as np
import time

# Constants
N_POINTS = 10000  # Number of points
DIMENSIONS = 2
K = 6  # Number of clusters
MAX_ITERATIONS = 15

# Function to generate predefined clusters around fixed centroids
def generate_fixed_clusters():
    predefined_centroids = np.array([
        [1.0, 1.0],
        [5.0, 5.0],
        [9.0, 9.0],
        [13.0, 13.0],
        [17.0, 17.0],
        [21.0, 21.0]
    ])
    points_per_cluster = N_POINTS // K
    points = np.zeros((N_POINTS, DIMENSIONS))

    for i in range(K):
        for j in range(points_per_cluster):
            index = i * points_per_cluster + j
            points[index] = predefined_centroids[i]

    return points

# Simple function to calculate Euclidean distance
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# K-means clustering functions (assign clusters and update centroids)
def assign_clusters(points, centroids):
    clusters = np.zeros(N_POINTS, dtype=int)
    for i in range(N_POINTS):
        distances = np.array([euclidean_distance(points[i], centroids[j]) for j in range(K)])
        clusters[i] = np.argmin(distances)
    return clusters

def update_centroids(points, clusters):
    new_centroids = np.zeros((K, DIMENSIONS))
    for j in range(K):
        points_in_cluster = points[clusters == j]
        if len(points_in_cluster) > 0:
            new_centroids[j] = np.mean(points_in_cluster, axis=0)
    return new_centroids

# Function to print centroids
def print_centroids(title, centroids):
    print(f"{title}:")
    for i in range(K):
        print(f"Centroid {i}: {centroids[i]}")

# Main function to perform K-means clustering
def kmeans_clustering():
    points = generate_fixed_clusters()

    # Initialize centroids with predefined values (same as in the DPU code)
    centroids = np.array([
        [1.1, 1.1],
        [5.1, 5.1],
        [9.1, 9.1],
        [13.1, 13.1],
        [17.1, 17.1],
        [21.1, 21.1]
    ])

    print_centroids("Initial Centroids", centroids)

    # Log total time taken
    total_start_time = time.time()

    # Perform K-means clustering
    for iteration in range(MAX_ITERATIONS):
        start_time = time.time()
        clusters = assign_clusters(points, centroids)
        print(f"Assign clusters duration: {time.time() - start_time} seconds")

        start_time = time.time()
        centroids = update_centroids(points, clusters)
        print(f"Update centroids duration: {time.time() - start_time} seconds")

        print_centroids(f"Iteration {iteration + 1}: Updated Centroids", centroids)

    total_end_time = time.time()
    print(f"Total duration: {total_end_time - total_start_time} seconds")

    print_centroids("Final Centroids", centroids)

# Run the main function
kmeans_clustering()
# Out:
# Initial Centroids:
# Centroid 0: [1.1 1.1]
# Centroid 1: [5.1 5.1]
# Centroid 2: [9.1 9.1]
# Centroid 3: [13.1 13.1]
# Centroid 4: [17.1 17.1]
# Centroid 5: [21.1 21.1]
# Assign clusters duration: 1.0475986003875732 seconds
# Update centroids duration: 0.001399993896484375 seconds
# Iteration 1: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7991328239440918 seconds
# Update centroids duration: 0.0017099380493164062 seconds
# Iteration 2: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.6813375949859619 seconds
# Update centroids duration: 0.0017039775848388672 seconds
# Iteration 3: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7851071357727051 seconds
# Update centroids duration: 0.0008909702301025391 seconds
# Iteration 4: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.8036627769470215 seconds
# Update centroids duration: 0.0012011528015136719 seconds
# Iteration 5: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.806964635848999 seconds
# Update centroids duration: 0.0012183189392089844 seconds
# Iteration 6: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7783141136169434 seconds
# Update centroids duration: 0.001210927963256836 seconds
# Iteration 7: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7617828845977783 seconds
# Update centroids duration: 0.0008492469787597656 seconds
# Iteration 8: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7199385166168213 seconds
# Update centroids duration: 0.0031740665435791016 seconds
# Iteration 9: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.6250193119049072 seconds
# Update centroids duration: 0.0013241767883300781 seconds
# Iteration 10: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7304587364196777 seconds
# Update centroids duration: 0.0032355785369873047 seconds
# Iteration 11: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.5894532203674316 seconds
# Update centroids duration: 0.0016629695892333984 seconds
# Iteration 12: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.8495314121246338 seconds
# Update centroids duration: 0.001199483871459961 seconds
# Iteration 13: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7646322250366211 seconds
# Update centroids duration: 0.0011446475982666016 seconds
# Iteration 14: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Assign clusters duration: 0.7583448886871338 seconds
# Update centroids duration: 0.0010974407196044922 seconds
# Iteration 15: Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Total duration: 11.583199501037598 seconds
# Final Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]

# %%
import numpy as np
import time

# Constants
N_POINTS = 10000  # Number of points
DIMENSIONS = 2
K = 6  # Number of clusters
MAX_ITERATIONS = 15

# Generate predefined clusters around fixed centroids
def generate_fixed_clusters():
    predefined_centroids = np.array([
        [1.0, 1.0],   # Centroid for cluster 1
        [5.0, 5.0],   # Centroid for cluster 2
        [9.0, 9.0],   # Centroid for cluster 3
        [13.0, 13.0], # Centroid for cluster 4
        [17.0, 17.0], # Centroid for cluster 5
        [21.0, 21.0]  # Centroid for cluster 6
    ])
    points = np.zeros((N_POINTS, DIMENSIONS))
    points_per_cluster = N_POINTS // K

    for i in range(K):
        for j in range(points_per_cluster):
            index = i * points_per_cluster + j
            points[index] = predefined_centroids[i]
    return points

# Simple function to calculate Euclidean distance
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# K-means clustering functions (assign clusters and update centroids)
def assign_clusters(points, centroids):
    clusters = np.zeros(N_POINTS, dtype=int)
    for i in range(N_POINTS):
        distances = np.array([euclidean_distance(points[i], centroids[j]) for j in range(K)])
        clusters[i] = np.argmin(distances)
    return clusters

def update_centroids(points, clusters):
    new_centroids = np.zeros((K, DIMENSIONS))
    count = np.zeros(K)

    for i in range(N_POINTS):
        new_centroids[clusters[i]] += points[i]
        count[clusters[i]] += 1

    for j in range(K):
        if count[j] != 0:
            new_centroids[j] /= count[j]

    return new_centroids

# Function to print centroids
def print_centroids(title, centroids):
    print(f"{title}:")
    for i in range(K):
        print(f"Centroid {i}: {centroids[i]}")

# Main function to run K-means clustering
def kmeans_clustering():
    # Generate fixed clusters
    points = generate_fixed_clusters()

    # Initialize centroids with predefined values
    centroids = np.array([
        [1.1, 1.1],
        [5.1, 5.1],
        [9.1, 9.1],
        [13.1, 13.1],
        [17.1, 17.1],
        [21.1, 21.1]
    ])

    print_centroids("Initial Centroids", centroids)

    # Start total time measurement
    total_start_time = time.time()

    for iteration in range(MAX_ITERATIONS):
        print(f"\nIteration {iteration + 1}:")

        # Measure assign clusters duration
        start_time = time.time()
        clusters = assign_clusters(points, centroids)
        assign_duration = time.time() - start_time
        print(f"Assign clusters duration: {assign_duration} seconds")

        # Measure update centroids duration
        start_time = time.time()
        centroids = update_centroids(points, clusters)
        update_duration = time.time() - start_time
        print(f"Update centroids duration: {update_duration} seconds")

        print_centroids("Updated Centroids", centroids)

    # End total time measurement
    total_end_time = time.time()
    print(f"Total duration: {total_end_time - total_start_time} seconds")

    print_centroids("Final Centroids", centroids)

# Run the main function
kmeans_clustering()
# Out:
# Initial Centroids:
# Centroid 0: [1.1 1.1]
# Centroid 1: [5.1 5.1]
# Centroid 2: [9.1 9.1]
# Centroid 3: [13.1 13.1]
# Centroid 4: [17.1 17.1]
# Centroid 5: [21.1 21.1]
#
# Iteration 1:
# Assign clusters duration: 0.6656386852264404 seconds
# Update centroids duration: 0.017459630966186523 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 2:
# Assign clusters duration: 0.8588299751281738 seconds
# Update centroids duration: 0.018429040908813477 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 3:
# Assign clusters duration: 0.8467097282409668 seconds
# Update centroids duration: 0.017789125442504883 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 4:
# Assign clusters duration: 0.7313430309295654 seconds
# Update centroids duration: 0.017383337020874023 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 5:
# Assign clusters duration: 0.7618165016174316 seconds
# Update centroids duration: 0.02042412757873535 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 6:
# Assign clusters duration: 0.7715170383453369 seconds
# Update centroids duration: 0.017880678176879883 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 7:
# Assign clusters duration: 0.8066582679748535 seconds
# Update centroids duration: 0.033144235610961914 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 8:
# Assign clusters duration: 0.8127624988555908 seconds
# Update centroids duration: 0.03074955940246582 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 9:
# Assign clusters duration: 0.8159825801849365 seconds
# Update centroids duration: 0.03403735160827637 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 10:
# Assign clusters duration: 0.8010079860687256 seconds
# Update centroids duration: 0.01703929901123047 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 11:
# Assign clusters duration: 0.6806929111480713 seconds
# Update centroids duration: 0.017522573471069336 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 12:
# Assign clusters duration: 0.7081141471862793 seconds
# Update centroids duration: 0.01738452911376953 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 13:
# Assign clusters duration: 0.6062884330749512 seconds
# Update centroids duration: 0.017424345016479492 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 14:
# Assign clusters duration: 0.8393027782440186 seconds
# Update centroids duration: 0.03381657600402832 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
#
# Iteration 15:
# Assign clusters duration: 0.8383498191833496 seconds
# Update centroids duration: 0.03361368179321289 seconds
# Updated Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Total duration: 11.966977596282959 seconds
# Final Centroids:
# Centroid 0: [0.99760479 0.99760479]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]

# %%
import numpy as np
import time

# Constants
N_POINTS = 10000  # Number of points
DIMENSIONS = 2
K = 15  # Number of clusters
MAX_ITERATIONS = 15

# Generate predefined clusters around fixed centroids
def generate_fixed_clusters():
    predefined_centroids = np.array([
        [1.0, 1.0],   # Centroid for cluster 1
        [5.0, 5.0],   # Centroid for cluster 2
        [9.0, 9.0],   # Centroid for cluster 3
        [13.0, 13.0], # Centroid for cluster 4
        [17.0, 17.0], # Centroid for cluster 5
        [21.0, 21.0], # Centroid for cluster 6
        [25.0, 25.0], # Centroid for cluster 7
        [29.0, 29.0], # Centroid for cluster 8
        [33.0, 33.0], # Centroid for cluster 9
        [37.0, 37.0], # Centroid for cluster 10
        [41.0, 41.0], # Centroid for cluster 11
        [45.0, 45.0], # Centroid for cluster 12
        [49.0, 49.0], # Centroid for cluster 13
        [53.0, 53.0], # Centroid for cluster 14
        [57.0, 57.0]  # Centroid for cluster 15
    ])
    points = np.zeros((N_POINTS, DIMENSIONS))
    points_per_cluster = N_POINTS // K

    for i in range(K):
        for j in range(points_per_cluster):
            index = i * points_per_cluster + j
            points[index] = predefined_centroids[i]
    return points

# Simple function to calculate Euclidean distance
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# K-means clustering functions (assign clusters and update centroids)
def assign_clusters(points, centroids):
    clusters = np.zeros(N_POINTS, dtype=int)
    for i in range(N_POINTS):
        distances = np.array([euclidean_distance(points[i], centroids[j]) for j in range(K)])
        clusters[i] = np.argmin(distances)
    return clusters

def update_centroids(points, clusters):
    new_centroids = np.zeros((K, DIMENSIONS))
    count = np.zeros(K)

    for i in range(N_POINTS):
        new_centroids[clusters[i]] += points[i]
        count[clusters[i]] += 1

    for j in range(K):
        if count[j] != 0:
            new_centroids[j] /= count[j]

    return new_centroids

# Function to print centroids
def print_centroids(title, centroids):
    print(f"{title}:")
    for i in range(K):
        print(f"Centroid {i}: {centroids[i]}")

# Main function to run K-means clustering
def kmeans_clustering():
    # Generate fixed clusters
    points = generate_fixed_clusters()

    # Initialize centroids with predefined values
    centroids = np.array([
        [1.0, 1.0],   # Centroid for cluster 1
        [5.0, 5.0],   # Centroid for cluster 2
        [9.0, 9.0],   # Centroid for cluster 3
        [13.0, 13.0], # Centroid for cluster 4
        [17.0, 17.0], # Centroid for cluster 5
        [21.0, 21.0], # Centroid for cluster 6
        [25.0, 25.0], # Centroid for cluster 7
        [29.0, 29.0], # Centroid for cluster 8
        [33.0, 33.0], # Centroid for cluster 9
        [37.0, 37.0], # Centroid for cluster 10
        [41.0, 41.0], # Centroid for cluster 11
        [45.0, 45.0], # Centroid for cluster 12
        [49.0, 49.0], # Centroid for cluster 13
        [53.0, 53.0], # Centroid for cluster 14
        [57.0, 57.0]  # Centroid for cluster 15

    ])

    print_centroids("Initial Centroids", centroids)

    # Start total time measurement
    total_start_time = time.time()

    for iteration in range(MAX_ITERATIONS):
        print(f"\nIteration {iteration + 1}:")

        # Measure assign clusters duration
        start_time = time.time()
        clusters = assign_clusters(points, centroids)
        assign_duration = time.time() - start_time
        print(f"Assign clusters duration: {assign_duration} seconds")

        # Measure update centroids duration
        start_time = time.time()
        centroids = update_centroids(points, clusters)
        update_duration = time.time() - start_time
        print(f"Update centroids duration: {update_duration} seconds")

        print_centroids("Updated Centroids", centroids)

    # End total time measurement
    total_end_time = time.time()
    print(f"Total duration: {total_end_time - total_start_time} seconds")

    print_centroids("Final Centroids", centroids)

# Run the main function
kmeans_clustering()
# Out:
# Initial Centroids:
# Centroid 0: [1. 1.]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 1:
# Assign clusters duration: 1.6495773792266846 seconds
# Update centroids duration: 0.020070791244506836 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 2:
# Assign clusters duration: 1.5950143337249756 seconds
# Update centroids duration: 0.021442413330078125 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 3:
# Assign clusters duration: 1.8559496402740479 seconds
# Update centroids duration: 0.03312206268310547 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 4:
# Assign clusters duration: 1.887436866760254 seconds
# Update centroids duration: 0.02230095863342285 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 5:
# Assign clusters duration: 1.4993348121643066 seconds
# Update centroids duration: 0.019913911819458008 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 6:
# Assign clusters duration: 1.5379655361175537 seconds
# Update centroids duration: 0.020233631134033203 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 7:
# Assign clusters duration: 1.4951322078704834 seconds
# Update centroids duration: 0.023133277893066406 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 8:
# Assign clusters duration: 1.6102516651153564 seconds
# Update centroids duration: 0.020594120025634766 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 9:
# Assign clusters duration: 1.5484201908111572 seconds
# Update centroids duration: 0.01915717124938965 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 10:
# Assign clusters duration: 1.5514390468597412 seconds
# Update centroids duration: 0.02049422264099121 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 11:
# Assign clusters duration: 1.8227238655090332 seconds
# Update centroids duration: 0.03290081024169922 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 12:
# Assign clusters duration: 1.8476488590240479 seconds
# Update centroids duration: 0.02082371711730957 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 13:
# Assign clusters duration: 1.4938640594482422 seconds
# Update centroids duration: 0.020591020584106445 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 14:
# Assign clusters duration: 1.525658130645752 seconds
# Update centroids duration: 0.019069433212280273 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
#
# Iteration 15:
# Assign clusters duration: 1.5455844402313232 seconds
# Update centroids duration: 0.020220041275024414 seconds
# Updated Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
# Total duration: 24.928595304489136 seconds
# Final Centroids:
# Centroid 0: [0.9852071 0.9852071]
# Centroid 1: [5. 5.]
# Centroid 2: [9. 9.]
# Centroid 3: [13. 13.]
# Centroid 4: [17. 17.]
# Centroid 5: [21. 21.]
# Centroid 6: [25. 25.]
# Centroid 7: [29. 29.]
# Centroid 8: [33. 33.]
# Centroid 9: [37. 37.]
# Centroid 10: [41. 41.]
# Centroid 11: [45. 45.]
# Centroid 12: [49. 49.]
# Centroid 13: [53. 53.]
# Centroid 14: [57. 57.]
